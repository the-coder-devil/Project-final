# %%
import pandas as pd

weather = pd.read_csv("Data_ND-2020-today.csv", index_col= "DATE")

# %%
weather
# Out:
#                 STATION                 NAME  PRCP  TAVG  TMAX  TMIN
# DATE
# 2020-01-01  IN022023000  NEW DELHI PALAM, IN   NaN    53   NaN  38.0
# 2020-01-02  IN022023000  NEW DELHI PALAM, IN   NaN    59  70.0  42.0
# 2020-01-03  IN022023000  NEW DELHI PALAM, IN   NaN    60   NaN  47.0
# 2020-01-04  IN022023000  NEW DELHI PALAM, IN   NaN    58  72.0  47.0
# 2020-01-05  IN022023000  NEW DELHI PALAM, IN   NaN    58  69.0  45.0
# ...                 ...                  ...   ...   ...   ...   ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN  0.79    59  65.0   NaN
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN  0.08    54  65.0   NaN
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN  0.00    59  70.0  45.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN  0.12    61  70.0  54.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN  0.02    59  69.0   NaN
#
# [1491 rows x 6 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
weather.apply(pd.isnull).sum()
# Out:
# STATION       0
# NAME          0
# PRCP       1134
# TAVG          0
# TMAX        534
# TMIN        571
# dtype: int64

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.760563
# TAVG       0.000000
# TMAX       0.358149
# TMIN       0.382964
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < 0.4]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'TAVG', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather
# Out:
#                 STATION                 NAME  TAVG  TMAX  TMIN
# DATE
# 2020-01-01  IN022023000  NEW DELHI PALAM, IN    53   NaN  38.0
# 2020-01-02  IN022023000  NEW DELHI PALAM, IN    59  70.0  42.0
# 2020-01-03  IN022023000  NEW DELHI PALAM, IN    60   NaN  47.0
# 2020-01-04  IN022023000  NEW DELHI PALAM, IN    58  72.0  47.0
# 2020-01-05  IN022023000  NEW DELHI PALAM, IN    58  69.0  45.0
# ...                 ...                  ...   ...   ...   ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN    59  65.0   NaN
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN    54  65.0   NaN
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN    59  70.0  45.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN    61  70.0  54.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN    59  69.0   NaN
#
# [1491 rows x 5 columns]

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                 name  tavg  tmax  tmin
# DATE
# 2020-01-01  IN022023000  NEW DELHI PALAM, IN    53   NaN  38.0
# 2020-01-02  IN022023000  NEW DELHI PALAM, IN    59  70.0  42.0
# 2020-01-03  IN022023000  NEW DELHI PALAM, IN    60   NaN  47.0
# 2020-01-04  IN022023000  NEW DELHI PALAM, IN    58  72.0  47.0
# 2020-01-05  IN022023000  NEW DELHI PALAM, IN    58  69.0  45.0
# ...                 ...                  ...   ...   ...   ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN    59  65.0   NaN
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN    54  65.0   NaN
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN    59  70.0  45.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN    61  70.0  54.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN    59  69.0   NaN
#
# [1491 rows x 5 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                 name  tavg  tmax  tmin
# DATE
# 2020-01-01  IN022023000  NEW DELHI PALAM, IN    53   NaN  38.0
# 2020-01-02  IN022023000  NEW DELHI PALAM, IN    59  70.0  42.0
# 2020-01-03  IN022023000  NEW DELHI PALAM, IN    60  70.0  47.0
# 2020-01-04  IN022023000  NEW DELHI PALAM, IN    58  72.0  47.0
# 2020-01-05  IN022023000  NEW DELHI PALAM, IN    58  69.0  45.0
# ...                 ...                  ...   ...   ...   ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN    59  65.0  49.0
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN    54  65.0  49.0
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN    59  70.0  45.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN    61  70.0  54.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN    59  69.0  54.0
#
# [1491 rows x 5 columns]

# %%
weather = weather.bfill()

# %%
weather
# Out:
#                 station                 name  tavg  tmax  tmin
# DATE
# 2020-01-01  IN022023000  NEW DELHI PALAM, IN    53  70.0  38.0
# 2020-01-02  IN022023000  NEW DELHI PALAM, IN    59  70.0  42.0
# 2020-01-03  IN022023000  NEW DELHI PALAM, IN    60  70.0  47.0
# 2020-01-04  IN022023000  NEW DELHI PALAM, IN    58  72.0  47.0
# 2020-01-05  IN022023000  NEW DELHI PALAM, IN    58  69.0  45.0
# ...                 ...                  ...   ...   ...   ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN    59  65.0  49.0
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN    54  65.0  49.0
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN    59  70.0  45.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN    61  70.0  54.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN    59  69.0  54.0
#
# [1491 rows x 5 columns]

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# tavg       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# tavg         int64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04', '2020-01-05',
#        '2020-01-06', '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#        ...
#        '2024-01-27', '2024-01-28', '2024-01-29', '2024-01-30', '2024-01-31',
#        '2024-02-01', '2024-02-02', '2024-02-03', '2024-02-04', '2024-02-05'],
#       dtype='object', name='DATE', length=1491)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2024-01-27', '2024-01-28', '2024-01-29', '2024-01-30',
#                '2024-01-31', '2024-02-01', '2024-02-02', '2024-02-03',
#                '2024-02-04', '2024-02-05'],
#               dtype='datetime64[ns]', name='DATE', length=1491, freq=None)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 2020    366
# 2021    362
# 2022    362
# 2023    365
# 2024     36
# Name: DATE, dtype: int64

# %%
weather
# Out:
#                 station                 name  tavg  tmax  tmin
# DATE
# 2020-01-01  IN022023000  NEW DELHI PALAM, IN    53  70.0  38.0
# 2020-01-02  IN022023000  NEW DELHI PALAM, IN    59  70.0  42.0
# 2020-01-03  IN022023000  NEW DELHI PALAM, IN    60  70.0  47.0
# 2020-01-04  IN022023000  NEW DELHI PALAM, IN    58  72.0  47.0
# 2020-01-05  IN022023000  NEW DELHI PALAM, IN    58  69.0  45.0
# ...                 ...                  ...   ...   ...   ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN    59  65.0  49.0
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN    54  65.0  49.0
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN    59  70.0  45.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN    61  70.0  54.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN    59  69.0  54.0
#
# [1491 rows x 5 columns]

# %%
import matplotlib as mp
weather['tavg'].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
weather["tavg"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
weather['target'] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                 name  tavg  tmax  tmin  target
# DATE
# 2020-01-01  IN022023000  NEW DELHI PALAM, IN    53  70.0  38.0    70.0
# 2020-01-02  IN022023000  NEW DELHI PALAM, IN    59  70.0  42.0    70.0
# 2020-01-03  IN022023000  NEW DELHI PALAM, IN    60  70.0  47.0    72.0
# 2020-01-04  IN022023000  NEW DELHI PALAM, IN    58  72.0  47.0    69.0
# 2020-01-05  IN022023000  NEW DELHI PALAM, IN    58  69.0  45.0    69.0
# ...                 ...                  ...   ...   ...   ...     ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN    59  65.0  49.0    65.0
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN    54  65.0  49.0    70.0
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN    59  70.0  45.0    70.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN    61  70.0  54.0    69.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN    59  69.0  54.0     NaN
#
# [1491 rows x 6 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                 name  tavg  tmax  tmin  target
# DATE
# 2020-01-01  IN022023000  NEW DELHI PALAM, IN    53  70.0  38.0    70.0
# 2020-01-02  IN022023000  NEW DELHI PALAM, IN    59  70.0  42.0    70.0
# 2020-01-03  IN022023000  NEW DELHI PALAM, IN    60  70.0  47.0    72.0
# 2020-01-04  IN022023000  NEW DELHI PALAM, IN    58  72.0  47.0    69.0
# 2020-01-05  IN022023000  NEW DELHI PALAM, IN    58  69.0  45.0    69.0
# ...                 ...                  ...   ...   ...   ...     ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN    59  65.0  49.0    65.0
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN    54  65.0  49.0    70.0
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN    59  70.0  45.0    70.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN    61  70.0  54.0    69.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN    59  69.0  54.0    69.0
#
# [1491 rows x 6 columns]

# %%
from sklearn.linear_model import Ridge

# %%
rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['tavg', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather, model, predictors, start = 10, step=10):
    all_predictions = []

    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]

        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])

        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)

        combined.columns = ["actual","prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()

        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction      diff
# DATE
# 2020-01-11    58.0   62.276896  4.276896
# 2020-01-12    70.0   62.897252  7.102748
# 2020-01-13    69.0   68.314919  0.685081
# 2020-01-14    69.0   64.520585  4.479415
# 2020-01-15    65.0   67.736577  2.736577
# ...            ...         ...       ...
# 2024-02-01    65.0   67.267558  2.267558
# 2024-02-02    70.0   64.599659  5.400341
# 2024-02-03    70.0   71.078205  1.078205
# 2024-02-04    69.0   70.650572  1.650572
# 2024-02-05    69.0   68.958638  0.041362
#
# [1481 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"], predictions['prediction'])
# Out:
# 1.7230815930995205

# %%
predictions["diff"].mean()
# Out:
# 1.7230815930995205

# %%
def pct_diff(old,new):
    return (new-old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"

    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label],weather[col])
    return weather

rolling_horizons = [3,14]

for horizon in rolling_horizons:
    for col in ["tmax","tmin"]:
        weather = compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#                 station                 name  tavg  tmax  tmin  target  \
# DATE
# 2020-01-01  IN022023000  NEW DELHI PALAM, IN    53  70.0  38.0    70.0
# 2020-01-02  IN022023000  NEW DELHI PALAM, IN    59  70.0  42.0    70.0
# 2020-01-03  IN022023000  NEW DELHI PALAM, IN    60  70.0  47.0    72.0
# 2020-01-04  IN022023000  NEW DELHI PALAM, IN    58  72.0  47.0    69.0
# 2020-01-05  IN022023000  NEW DELHI PALAM, IN    58  69.0  45.0    69.0
# ...                 ...                  ...   ...   ...   ...     ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN    59  65.0  49.0    65.0
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN    54  65.0  49.0    70.0
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN    59  70.0  45.0    70.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN    61  70.0  54.0    69.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN    59  69.0  54.0    69.0
#
#             rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  \
# DATE
# ...

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                 name  tavg  tmax  tmin  target  \
# DATE
# 2020-01-15  IN022023000  NEW DELHI PALAM, IN    56  69.0  44.0    65.0
# 2020-01-16  IN022023000  NEW DELHI PALAM, IN    54  65.0  44.0    65.0
# 2020-01-17  IN022023000  NEW DELHI PALAM, IN    55  65.0  51.0    61.0
# 2020-01-18  IN022023000  NEW DELHI PALAM, IN    54  61.0  51.0    60.0
# 2020-01-19  IN022023000  NEW DELHI PALAM, IN    50  60.0  43.0    60.0
# ...                 ...                  ...   ...   ...   ...     ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN    59  65.0  49.0    65.0
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN    54  65.0  49.0    70.0
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN    59  70.0  45.0    70.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN    61  70.0  54.0    69.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN    59  69.0  54.0    69.0
#
#             rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  \
# DATE
# ...

# %%
weather = weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys = False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                 name  tavg  tmax  tmin  target  \
# DATE
# 2020-01-15  IN022023000  NEW DELHI PALAM, IN    56  69.0  44.0    65.0
# 2020-01-16  IN022023000  NEW DELHI PALAM, IN    54  65.0  44.0    65.0
# 2020-01-17  IN022023000  NEW DELHI PALAM, IN    55  65.0  51.0    61.0
# 2020-01-18  IN022023000  NEW DELHI PALAM, IN    54  61.0  51.0    60.0
# 2020-01-19  IN022023000  NEW DELHI PALAM, IN    50  60.0  43.0    60.0
# ...                 ...                  ...   ...   ...   ...     ...
# 2024-02-01  IN022023000  NEW DELHI PALAM, IN    59  65.0  49.0    65.0
# 2024-02-02  IN022023000  NEW DELHI PALAM, IN    54  65.0  49.0    70.0
# 2024-02-03  IN022023000  NEW DELHI PALAM, IN    59  70.0  45.0    70.0
# 2024-02-04  IN022023000  NEW DELHI PALAM, IN    61  70.0  54.0    69.0
# 2024-02-05  IN022023000  NEW DELHI PALAM, IN    59  69.0  54.0    69.0
#
#             rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  \
# DATE
# ...

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['tavg', 'tmax', 'tmin', 'rolling_3_tmax', 'rolling_3_tmax_pct',
#        'rolling_3_tmin', 'rolling_3_tmin_pct', 'rolling_14_tmax',
#        'rolling_14_tmax_pct', 'rolling_14_tmin', 'rolling_14_tmin_pct',
#        'month_avg_tmax', 'month_avg_tmin', 'day_avg_tmax', 'day_avg_tmin'],
#       dtype='object')

# %%
predictons = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 1.7230815930995205

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2023-06-24    84.0   99.793099  15.793099
# 2021-04-27   110.0   97.297344  12.702656
# 2022-12-27    71.0   58.831495  12.168505
# 2022-04-20    97.0  108.842991  11.842991
# 2021-07-27    85.0   95.468373  10.468373
# ...            ...         ...        ...
# 2021-07-30    92.0   92.005778   0.005778
# 2020-03-01    83.0   82.994917   0.005083
# 2020-11-29    75.0   74.996011   0.003989
# 2020-11-30    75.0   74.996011   0.003989
# 2021-08-13    98.0   97.999350   0.000650
#
# [1481 rows x 3 columns]

# %%
weather.loc["2023-06-17":"2023-06-27"]
# Out:
#                 station                 name  tavg   tmax  tmin  target  \
# DATE
# 2023-06-17  IN022023000  NEW DELHI PALAM, IN    90  103.0  77.0   100.0
# 2023-06-18  IN022023000  NEW DELHI PALAM, IN    88  100.0  77.0    93.0
# 2023-06-19  IN022023000  NEW DELHI PALAM, IN    83   93.0  78.0    98.0
# 2023-06-20  IN022023000  NEW DELHI PALAM, IN    88   98.0  79.0    97.0
# 2023-06-21  IN022023000  NEW DELHI PALAM, IN    88   97.0  78.0    99.0
# 2023-06-22  IN022023000  NEW DELHI PALAM, IN    91   99.0  78.0    99.0
# 2023-06-23  IN022023000  NEW DELHI PALAM, IN    91   99.0  79.0    99.0
# 2023-06-24  IN022023000  NEW DELHI PALAM, IN    89   99.0  79.0    84.0
# 2023-06-25  IN022023000  NEW DELHI PALAM, IN    79   84.0  75.0    91.0
# 2023-06-26  IN022023000  NEW DELHI PALAM, IN    84   91.0  79.0    94.0
# 2023-06-27  IN022023000  NEW DELHI PALAM, IN    85   94.0  79.0    95.0
#
#             rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  \
# DATE
# ...

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
weather['tavg'].plot()
weather['target'].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>
